# %% [markdown]
# Group members:
# Aidan McGinnis - Aidan.McGinnis001@umb.edu;
# Kasey Omahony - kasey.omahony001@umb.edu;
# Romario Joseph - romario.joseph001@umb.edu;
# Sumaya Abdullahi - sumaya.abdullahi001@umb.edu;
# Tydina Muhammad - tydina.muhammad001@umb.edu, and
# Vitoria Gomes de Mattos Sousa - gomesdemattossous001@umb.edu.

# %% [markdown]
# Species: Eastern Gray Squirrel (Sciurus carolinensis)

# %% [markdown]
# Body parts labelled for the species using Deep Lab Cut:

# %%
import IPython
from IPython.display import Image

Image("https://raw.githubusercontent.com/KRASVT/GSquirrel/main/Body%20Parts%20Labelled.png")

# %% [markdown]
# Higher Loss Curve demonstrating that the machine has been trained well:

# %%
import IPython
from IPython.display import Image

Image("https://raw.githubusercontent.com/KRASVT/GSquirrel/main/Loss%20Curve.png")

# %% [markdown]
# RSME Graph demonstrating pixel errors under 0.6 p-cutoff mark:

# %%
import IPython
from IPython.display import Image

Image("https://raw.githubusercontent.com/KRASVT/GSquirrel/main/RSME.png")

# %% [markdown]
# Deep Lab Cut plots:

# %% [markdown]
# Body parts plotted in space -

# %% [markdown]
# <img src="https://raw.githubusercontent.com/KRASVT/GSquirrel/main/Analytical_Behaviorism_PresentationFiles/Squirrel%20video%205_Body%20parts%20plotted%20in%20space.png">

# %% [markdown]
# All Body Parts Across Time -

# %% [markdown]
# <img src="https://raw.githubusercontent.com/KRASVT/GSquirrel/main/Analytical_Behaviorism_PresentationFiles/Squirrel%20video%205_All%20body%20parts%20across%20time.png">

# %% [markdown]
# Every body part likelihood over time -

# %% [markdown]
# <img src="https://raw.githubusercontent.com/KRASVT/GSquirrel/main/Analytical_Behaviorism_PresentationFiles/Squirrel%20video%205_Every%20body%20part%20likelihood%20over%20time.png">

# %% [markdown]
# Consecutive coordinate differences -

# %% [markdown]
# <img src="https://raw.githubusercontent.com/KRASVT/GSquirrel/main/Analytical_Behaviorism_PresentationFiles/Squirrel%20video%205_Consecutive%20coordinate%20differences.png">

# %% [markdown]
# Videos used for Deep Lab Cut (DLC) plots:

# %% [markdown]
# Squirrel video 5 - DLCLabelled -

# %%
import IPython
from IPython.display import Video

Video("https://github.com/KRASVT/GSquirrel/blob/main/Analytical_Behaviorism_PresentationFiles/Squirrel%20video%205_DLCLabelled.mp4?raw=true")
# Out:
# <video src="https://github.com/KRASVT/GSquirrel/blob/main/Analytical_Behaviorism_PresentationFiles/Squirrel%20video%205_DLCLabelled.mp4?raw=true" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# Squirrel video 5 - Before Labelling -

# %%
import IPython
from IPython.display import Video

Video("https://github.com/KRASVT/GSquirrel/blob/main/Analytical_Behaviorism_PresentationFiles/Squirrel%20video%205.mp4?raw=true")
# Out:
# <video src="https://github.com/KRASVT/GSquirrel/blob/main/Analytical_Behaviorism_PresentationFiles/Squirrel%20video%205.mp4?raw=true" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# Squirrels video 9 DLC Labelled -

# %%
import IPython
from IPython.display import Video

Video("https://github.com/KRASVT/GSquirrel/blob/main/Analytical_Behaviorism_PresentationFiles/Squirrel%20video%209_DLCLabelled.mp4?raw=true")
# Out:
# <video src="https://github.com/KRASVT/GSquirrel/blob/main/Analytical_Behaviorism_PresentationFiles/Squirrel%20video%209_DLCLabelled.mp4?raw=true" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# Squirrel video 9 - Before Labelling -

# %%
import IPython
from IPython.display import Video

Video("https://github.com/KRASVT/GSquirrel/blob/main/Analytical_Behaviorism_PresentationFiles/Squirrel%20video%209.mp4?raw=true")
# Out:
# <video src="https://github.com/KRASVT/GSquirrel/blob/main/Analytical_Behaviorism_PresentationFiles/Squirrel%20video%209.mp4?raw=true" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>
